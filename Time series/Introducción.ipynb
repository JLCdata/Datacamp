# %% [markdown]
# # Working with Time Series in Pandas

# %%
import pandas as pd
from datetime import datetime
import numpy as np

# %% [markdown]
# **First time series**

# %%
time_stamp = pd.Timestamp(datetime(2017, 1, 1))

# %%
datetime(2017, 1, 1)
# Out:
# datetime.datetime(2017, 1, 1, 0, 0)

# %%
time_stamp
# Out:
# Timestamp('2017-01-01 00:00:00')

# %%
time_stamp.year
# Out:
# 2017

# %%
time_stamp.day
# Out:
# 1

# %%
period = pd.Period('2017-01')

# %%
period
# Out:
# Period('2017-01', 'M')

# %%
period.asfreq('D')
# Out:
# Period('2017-01-31', 'D')

# %%
period.to_timestamp()
# Out:
# Timestamp('2017-01-01 00:00:00')

# %%
period.to_timestamp().to_period('M')
# Out:
# Period('2017-01', 'M')

# %%
period+2
# Out:
# Period('2017-03', 'M')

# %%
u=pd.Timestamp('2017-01-31','M')
# Out:
# C:\Users\JOSELU~1\AppData\Local\Temp/ipykernel_9384/3007353215.py:1: FutureWarning: The 'freq' argument in Timestamp is deprecated and will be removed in a future version.
#   u=pd.Timestamp('2017-01-31','M')

# %%
index = pd.date_range(start='2017-1-1', periods=12, freq='M')

# %%
index
# Out:
# DatetimeIndex(['2017-01-31', '2017-02-28', '2017-03-31', '2017-04-30',
#                '2017-05-31', '2017-06-30', '2017-07-31', '2017-08-31',
#                '2017-09-30', '2017-10-31', '2017-11-30', '2017-12-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
index[0]
# Out:
# Timestamp('2017-01-31 00:00:00', freq='M')

# %%
index.to_period()
# Out:
# PeriodIndex(['2017-01', '2017-02', '2017-03', '2017-04', '2017-05', '2017-06',
#              '2017-07', '2017-08', '2017-09', '2017-10', '2017-11', '2017-12'],
#             dtype='period[M]')

# %%
pd.DataFrame({'data': index})
# Out:
#          data
# 0  2017-01-31
# 1  2017-02-28
# 2  2017-03-31
# 3  2017-04-30
# 4  2017-05-31
# 5  2017-06-30
# 6  2017-07-31
# 7  2017-08-31
# 8  2017-09-30
# 9  2017-10-31
# 10 2017-11-30
# 11 2017-12-31

# %%
data = np.random.rand(12,2)
x=pd.DataFrame(data=data, index=index)
x
# Out:
#                    0         1
# 2017-01-31  0.333290  0.462044
# 2017-02-28  0.775593  0.141131
# 2017-03-31  0.647217  0.279284
# 2017-04-30  0.716618  0.598098
# 2017-05-31  0.456290  0.511610
# 2017-06-30  0.477557  0.720062
# 2017-07-31  0.120409  0.623900
# 2017-08-31  0.582845  0.226765
# 2017-09-30  0.671078  0.093531
# 2017-10-31  0.232293  0.717084
# 2017-11-30  0.350082  0.787926
# 2017-12-31  0.026900  0.759010

# %%
x.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)

# %%
pd.date_range(start='2017-1-1', periods=7, freq='D')
# Out:
# DatetimeIndex(['2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04',
#                '2017-01-05', '2017-01-06', '2017-01-07'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# **Indexing & resampling time series**

# %%
# Using plotly.express
import plotly.express as px

df = px.data.stocks()

# %%
df.date=pd.to_datetime(df.date)

# %%
# Permite tratar al dataframe como serie de tiempo
df.set_index("date",inplace=True)

# %%
df.plot(title="serie de tiempo",subplots=True)
# Out:
# array([<AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>],
#       dtype=object)

# %%
df.loc['2018']
# Out:
#                 GOOG      AAPL      AMZN        FB      NFLX      MSFT
# date
# 2018-01-01  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 2018-01-08  1.018172  1.011943  1.061881  0.959968  1.053526  1.015988
# 2018-01-15  1.032008  1.019771  1.053240  0.970243  1.049860  1.020524
# 2018-01-22  1.066783  0.980057  1.140676  1.016858  1.307681  1.066561
# 2018-01-29  1.008773  0.917143  1.163374  1.018357  1.273537  1.040708
# 2018-02-05  0.941528  0.893771  1.089868  0.942521  1.188009  0.999887
# 2018-02-12  0.993259  0.985314  1.178621  0.949211  1.326349  1.043202
# 2018-02-19  1.022282  1.002857  1.220365  0.980947  1.361636  1.066561
# 2018-02-26  0.978852  1.006914  1.220569  0.945250  1.433640  1.055108
# 2018-03-05  1.052448  1.028457  1.284549  0.991330  1.578361  1.094682
# 2018-03-12  1.030393  1.017257  1.278683  0.990581  1.516501  1.072684
# 2018-03-19  0.926821  0.942514  1.216753  0.853037  1.433116  0.988547
# 2018-03-26  0.936093  0.958743  1.177522  0.855178  1.406496  1.034925
# 2018-04-02  0.913639  0.962171  1.143263  0.841317  1.375542  1.023132
# 2018-04-09  0.933807  0.998457  1.164058  0.880492  1.484118  1.055448
# 2018-04-16  0.973445  0.946971  1.242731  0.889912  1.560884  1.077220
# 2018-04-23  0.934515  0.927543  1.279447  0.929034  1.484642  1.086518
# 2018-04-30  0.950990  1.050457  1.286224  0.945197  1.524311  1.079034
# 2018-05-07  0.996398  1.077657  1.304091  1.000749  1.554645  1.107835
# 2018-05-14  0.967457  1.064629  1.280871  0.977683  1.543788  1.092641
# 2018-05-21  0.975894  1.077600  1.309981  0.989671  1.672889  1.115319
# 2018-05-28  1.015668  1.087086  1.335519  1.038212  1.714034  1.142873
# 2018-06-04  1.016911  1.095429  1.370055  1.012042  1.717082  1.152398
# 2018-06-11  1.045390  1.079086  1.396074  1.048167  1.866660  1.135389
# 2018-06-18  1.048311  1.056686  1.395830  1.079690  1.957665  1.138564
# 2018-06-25  1.012175  1.057771  1.382918  1.039979  1.864041  1.118154
# 2018-07-02  1.034421  1.074114  1.391729  1.087664  1.944140  1.147069
# 2018-07-09  1.078559  1.093314  1.475039  1.109553  1.884852  1.195487
# 2018-07-16  1.075012  1.093943  1.475584  1.123575  1.719367  1.205012
# 2018-07-23  1.123631  1.091314  1.478489  0.935991  1.691557  1.221000
# 2018-07-30  1.110213  1.188514  1.483387  0.951458  1.633840  1.225082
# 2018-08-06  1.122824  1.185886  1.534650  0.964731  1.647078  1.235968
# 2018-08-13  1.089573  1.243314  1.531331  0.930158  1.508548  1.219866
# 2018-08-20  1.107437  1.235200  1.550181  0.934707  1.708748  1.229164
# 2018-08-27  1.105205  1.300743  1.637494  0.940487  1.750940  1.273727
# 2018-09-03  1.056794  1.264571  1.588159  0.872572  1.660460  1.227010
# 2018-09-10  1.063780  1.279086  1.602901  0.868718  1.736083  1.285520
# 2018-09-17  1.057937  1.243771  1.558008  0.871983  1.720034  1.295612
# 2018-09-24  1.082778  1.289943  1.629595  0.880171  1.781656  1.296859
# 2018-10-01  1.050008  1.281657  1.537376  0.842012  1.673175  1.271459
# 2018-10-08  1.007122  1.269200  1.455172  0.822799  1.617029  1.242431
# 2018-10-15  0.994765  1.253200  1.435174  0.824458  1.584218  1.232113
# 2018-10-22  0.972093  1.236000  1.336552  0.778004  1.427830  1.212836
# 2018-10-29  0.959682  1.185600  1.355037  0.804656  1.471975  1.203765
# 2018-11-05  0.967266  1.168400  1.393194  0.775809  1.445164  1.242431
# 2018-11-12  0.963039  1.105886  1.296362  0.746749  1.362970  1.227917
# 2018-11-19  0.928917  0.984514  1.222041  0.705004  1.232535  1.168727
# 2018-11-26  0.992924  1.020457  1.375083  0.752529  1.362589  1.257399
# 2018-12-03  0.940439  0.962800  1.325423  0.735456  1.262632  1.188570
# 2018-12-10  0.945447  0.945600  1.295141  0.770993  1.270727  1.202290
# 2018-12-17  0.888689  0.861314  1.120662  0.668718  1.173342  1.113845
# 2018-12-24  0.940893  0.892743  1.202483  0.712871  1.219487  1.138338
# 2018-12-31  0.971403  0.847200  1.281701  0.738293  1.417067  1.155800

# %%
df.loc['2018-3':'2019-1']
# Out:
#                 GOOG      AAPL      AMZN        FB      NFLX      MSFT
# date
# 2018-03-05  1.052448  1.028457  1.284549  0.991330  1.578361  1.094682
# 2018-03-12  1.030393  1.017257  1.278683  0.990581  1.516501  1.072684
# 2018-03-19  0.926821  0.942514  1.216753  0.853037  1.433116  0.988547
# 2018-03-26  0.936093  0.958743  1.177522  0.855178  1.406496  1.034925
# 2018-04-02  0.913639  0.962171  1.143263  0.841317  1.375542  1.023132
# 2018-04-09  0.933807  0.998457  1.164058  0.880492  1.484118  1.055448
# 2018-04-16  0.973445  0.946971  1.242731  0.889912  1.560884  1.077220
# 2018-04-23  0.934515  0.927543  1.279447  0.929034  1.484642  1.086518
# 2018-04-30  0.950990  1.050457  1.286224  0.945197  1.524311  1.079034
# 2018-05-07  0.996398  1.077657  1.304091  1.000749  1.554645  1.107835
# 2018-05-14  0.967457  1.064629  1.280871  0.977683  1.543788  1.092641
# 2018-05-21  0.975894  1.077600  1.309981  0.989671  1.672889  1.115319
# 2018-05-28  1.015668  1.087086  1.335519  1.038212  1.714034  1.142873
# 2018-06-04  1.016911  1.095429  1.370055  1.012042  1.717082  1.152398
# 2018-06-11  1.045390  1.079086  1.396074  1.048167  1.866660  1.135389
# 2018-06-18  1.048311  1.056686  1.395830  1.079690  1.957665  1.138564
# 2018-06-25  1.012175  1.057771  1.382918  1.039979  1.864041  1.118154
# 2018-07-02  1.034421  1.074114  1.391729  1.087664  1.944140  1.147069
# 2018-07-09  1.078559  1.093314  1.475039  1.109553  1.884852  1.195487
# 2018-07-16  1.075012  1.093943  1.475584  1.123575  1.719367  1.205012
# 2018-07-23  1.123631  1.091314  1.478489  0.935991  1.691557  1.221000
# 2018-07-30  1.110213  1.188514  1.483387  0.951458  1.633840  1.225082
# 2018-08-06  1.122824  1.185886  1.534650  0.964731  1.647078  1.235968
# 2018-08-13  1.089573  1.243314  1.531331  0.930158  1.508548  1.219866
# 2018-08-20  1.107437  1.235200  1.550181  0.934707  1.708748  1.229164
# 2018-08-27  1.105205  1.300743  1.637494  0.940487  1.750940  1.273727
# 2018-09-03  1.056794  1.264571  1.588159  0.872572  1.660460  1.227010
# 2018-09-10  1.063780  1.279086  1.602901  0.868718  1.736083  1.285520
# 2018-09-17  1.057937  1.243771  1.558008  0.871983  1.720034  1.295612
# 2018-09-24  1.082778  1.289943  1.629595  0.880171  1.781656  1.296859
# 2018-10-01  1.050008  1.281657  1.537376  0.842012  1.673175  1.271459
# 2018-10-08  1.007122  1.269200  1.455172  0.822799  1.617029  1.242431
# 2018-10-15  0.994765  1.253200  1.435174  0.824458  1.584218  1.232113
# 2018-10-22  0.972093  1.236000  1.336552  0.778004  1.427830  1.212836
# 2018-10-29  0.959682  1.185600  1.355037  0.804656  1.471975  1.203765
# 2018-11-05  0.967266  1.168400  1.393194  0.775809  1.445164  1.242431
# 2018-11-12  0.963039  1.105886  1.296362  0.746749  1.362970  1.227917
# 2018-11-19  0.928917  0.984514  1.222041  0.705004  1.232535  1.168727
# 2018-11-26  0.992924  1.020457  1.375083  0.752529  1.362589  1.257399
# 2018-12-03  0.940439  0.962800  1.325423  0.735456  1.262632  1.188570
# 2018-12-10  0.945447  0.945600  1.295141  0.770993  1.270727  1.202290
# 2018-12-17  0.888689  0.861314  1.120662  0.668718  1.173342  1.113845
# 2018-12-24  0.940893  0.892743  1.202483  0.712871  1.219487  1.138338
# 2018-12-31  0.971403  0.847200  1.281701  0.738293  1.417067  1.155800
# 2019-01-07  0.959137  0.870229  1.334722  0.769601  1.607648  1.165665
# 2019-01-14  0.996398  0.896114  1.379989  0.802997  1.614839  1.221340
# 2019-01-21  0.989803  0.901486  1.359137  0.797485  1.609838  1.215217
# 2019-01-28  1.007730  0.951543  1.323063  0.886861  1.618410  1.165438

# %%
df.loc['2018-3':'2019-1',"GOOG"]
# Out:
# date
# 2018-03-05    1.052448
# 2018-03-12    1.030393
# 2018-03-19    0.926821
# 2018-03-26    0.936093
# 2018-04-02    0.913639
# 2018-04-09    0.933807
# 2018-04-16    0.973445
# 2018-04-23    0.934515
# 2018-04-30    0.950990
# 2018-05-07    0.996398
# 2018-05-14    0.967457
# 2018-05-21    0.975894
# 2018-05-28    1.015668
# 2018-06-04    1.016911
# 2018-06-11    1.045390
# 2018-06-18    1.048311
# 2018-06-25    1.012175
# 2018-07-02    1.034421
# 2018-07-09    1.078559
# 2018-07-16    1.075012
# 2018-07-23    1.123631
# 2018-07-30    1.110213
# 2018-08-06    1.122824
# 2018-08-13    1.089573
# 2018-08-20    1.107437
# 2018-08-27    1.105205
# 2018-09-03    1.056794
# 2018-09-10    1.063780
# 2018-09-17    1.057937
# 2018-09-24    1.082778
# 2018-10-01    1.050008
# 2018-10-08    1.007122
# 2018-10-15    0.994765
# 2018-10-22    0.972093
# 2018-10-29    0.959682
# 2018-11-05    0.967266
# 2018-11-12    0.963039
# 2018-11-19    0.928917
# 2018-11-26    0.992924
# 2018-12-03    0.940439
# 2018-12-10    0.945447
# 2018-12-17    0.888689
# 2018-12-24    0.940893
# 2018-12-31    0.971403
# 2019-01-07    0.959137
# 2019-01-14    0.996398
# 2019-01-21    0.989803
# 2019-01-28    1.007730
# Name: GOOG, dtype: float64

# %%
df.index
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-08', '2018-01-15', '2018-01-22',
#                '2018-01-29', '2018-02-05', '2018-02-12', '2018-02-19',
#                '2018-02-26', '2018-03-05',
#                ...
#                '2019-10-28', '2019-11-04', '2019-11-11', '2019-11-18',
#                '2019-11-25', '2019-12-02', '2019-12-09', '2019-12-16',
#                '2019-12-23', '2019-12-30'],
#               dtype='datetime64[ns]', name='date', length=105, freq=None)

# %%
df.asfreq('M')
# Out:
#                 GOOG      AAPL      AMZN        FB      NFLX      MSFT
# date
# 2018-01-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-02-28       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-03-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-04-30  0.950990  1.050457  1.286224  0.945197  1.524311  1.079034
# 2018-05-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-06-30       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-07-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-08-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-09-30       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-10-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-11-30       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-12-31  0.971403  0.847200  1.281701  0.738293  1.417067  1.155800
# 2019-01-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2019-02-28       NaN       NaN       NaN       NaN       NaN       NaN
# 2019-03-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2019-04-30       NaN       NaN       NaN       NaN       NaN       NaN
# 2019-05-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2019-06-30       NaN       NaN       NaN       NaN       NaN       NaN
# 2019-07-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2019-08-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2019-09-30  1.096867  1.297200  1.415339  0.965748  1.299062  1.566164
# 2019-10-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2019-11-30       NaN       NaN       NaN       NaN       NaN       NaN

# %%
df.asfreq('d')
# Out:
#                 GOOG   AAPL     AMZN        FB      NFLX      MSFT
# date
# 2018-01-01  1.000000  1.000  1.00000  1.000000  1.000000  1.000000
# 2018-01-02       NaN    NaN      NaN       NaN       NaN       NaN
# 2018-01-03       NaN    NaN      NaN       NaN       NaN       NaN
# 2018-01-04       NaN    NaN      NaN       NaN       NaN       NaN
# 2018-01-05       NaN    NaN      NaN       NaN       NaN       NaN
# ...              ...    ...      ...       ...       ...       ...
# 2019-12-26       NaN    NaN      NaN       NaN       NaN       NaN
# 2019-12-27       NaN    NaN      NaN       NaN       NaN       NaN
# 2019-12-28       NaN    NaN      NaN       NaN       NaN       NaN
# 2019-12-29       NaN    NaN      NaN       NaN       NaN       NaN
# 2019-12-30  1.213014  1.678  1.50336  1.098475  1.540883  1.788185
#
# [729 rows x 6 columns]

# %% [markdown]
# **Lags, changes, and returns for stock price series**

# %%
#google = pd.read_csv('google.csv',parse_dates=['Date'],index_col='Date')

# %%
# Create 'lagged' and 'shifted'
#google['lagged'] = google.Close.shift(periods=-1)
#google['shifted'] = google.Close.shift()

# %%
df.GOOG.shift(periods=-1)
# Out:
# date
# 2018-01-01    1.018172
# 2018-01-08    1.032008
# 2018-01-15    1.066783
# 2018-01-22    1.008773
# 2018-01-29    0.941528
#                 ...
# 2019-12-02    1.222821
# 2019-12-09    1.224418
# 2019-12-16    1.226504
# 2019-12-23    1.213014
# 2019-12-30         NaN
# Name: GOOG, Length: 105, dtype: float64

# %%
df.GOOG.shift(periods=1)
# Out:
# date
# 2018-01-01         NaN
# 2018-01-08    1.000000
# 2018-01-15    1.018172
# 2018-01-22    1.032008
# 2018-01-29    1.066783
#                 ...
# 2019-12-02    1.183927
# 2019-12-09    1.216280
# 2019-12-16    1.222821
# 2019-12-23    1.224418
# 2019-12-30    1.226504
# Name: GOOG, Length: 105, dtype: float64
